# %% [markdown]
# # This is a title
# ### This is a subtitle
# - This is a bullet point
# * This is another bullet point
# <p> I think I'll use it to format all of my documents from now on.
# <P>
# *This is bold*

# %% [markdown]
# # New Section

# %% [markdown]
# # This is another section

# %%
print('My name is Bahja')
print(type(3.14))
print(type('3.14'))
# Out:
# My name is Bahja
# <class 'float'>
# <class 'str'>

# %%
print('The itsy bitsy spider\nclimbed up the waterspout.')
# Out:
# The itsy bitsy spider
# climbed up the waterspout.

# %%
print('Hello World')

# %% [markdown]
# # Using Multiple Arguments

# %%
print("1"+"2"+"3")
print(1,2,3)
print(1+2+3)
# Out:
# 123
# 1 2 3
# 6

# %%
print('c:\\users\\yusuf')
# Out:
# c:\users\yusuf

# %%
print(17 % 4)
# Out:
# 1

# %%
my_age = 33

your_age = 30

your_age = my_age

print(my_age)
# Out:
# 33

# %%
print('This is pence calaculat')
